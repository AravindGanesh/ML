# %% [markdown]
# # Gaussian Mixture Model

# %% [markdown]
# Implement the expectation maximization (EM) algorithm for estimating the parameters of a Gaussian Mixture Model (GMM). The GMM density is given by
# $$p(\mathbf{x}|\mathbf{θ}) = \sum_{k=1}^{K} w_k \mathcal{N}(\mathbf{x}; \mathbf{\mu}_k,\Sigma_k)$$
#
# where $x \in R^d , \mathcal{N}(\mathbf{x};\mathbf{\mu},\Sigma)$ is the multivariate Gaussian distribution with mean vector $\mathbf{\mu}$ and covariance matrix $Σ$. The parameter set $\mathbf{\theta} = [ w_1 , \dots, w_d , \mathbf{μ}_1 ,\dots, \mathbf{μ}_K, Σ_1 , \dots, Σ_K]$ . Your program must accept as inputs the observation matrix $X$ (of size $d \times N$), the vector dimension $d$ and the mixture size $K$ as inputs, and output the estimated parameter set $\mathbf{\hat{\theta}}$. Generate $X$ on your own and experiment by varying your choices of $\mathbf{\theta}$.

# %%
import numpy as np

# %%
# Generate dataset
def generate_dataset(d, N, K):
    '''
    means for generating data: (K, d) array with each d-dimensional sub-array as mean vector 
    for kth distribution. The kth mean vector contains d samples drawn from a uniform distribution
    between k and k+1 - this will be easy for observing outputs of Expectation Maximization.
    '''
    known_means = np.array([ np.random.uniform(high=k+1, low=k, size=d) for k in np.arange(K)])
    # covariance matrices for generating data
    # (K, d,d) array; each dxd matrix is positive semi-definite - valid covariance matrix for kth distribution
    A = np.array([np.random.normal(1, 1, (d,d)) for k in np.arange(K)])
    known_covs = np.array([np.matmul(P.T, P) for P in A])
    # number of samples in kth distribution; rand_k is array of these number of samples per each distribution
    while(True): 
        # this is to generate random k's and make sure that sum of k's is be N
        rand_k = np.random.uniform(high=1, low=0, size=K)
        rand_k = N*rand_k/np.sum(rand_k)
        rand_k = np.rint(rand_k).astype(np.int)
        if np.sum(rand_k) == N : break
    # generate N d-dimensional Random Gaussian vectors with means and covariances above
    # this is a list of samples from each Gaussian 
    mix = [np.random.multivariate_normal(known_means[i], known_covs[i], size=rand_k[i]) for i in np.arange(K)]
    # put these vectors in a Nxd array
    X = np.concatenate(mix, axis=0)
    return X, known_means, known_covs

# %%
# X, means, covs = generate_dataset(d=5,N=1000, K=3)
# X.shape
# Out:
# (1000, 5)

# %%
from Kmeans import Kmeans # Kmeans from previous assignment

# %% [markdown]
# Class for EM estimator on GMM.
#
# Reference: Bishop's Pattern Recognition and Machine Learning.

# %%
class GMM():
    def __init__(self,data, d, K):
        self.d = d
        self.X = data
        self.K = K
        self.N = len(X)
        #initalization using kmeans
        kmeans = Kmeans(X=data, K=K)
        kmeans.cluster(n_iter=1)
        self.means = kmeans.means
        # covariances are initalized by finding covariances of each cluster
        mixtures = kmeans.get_clusters()
        self.covars = np.array([np.cov(mixture, rowvar=False) for mixture in mixtures])
        # inialize mixing coefficients by fractions of number of data points in each cluster
        self.w = np.array([np.mean(kmeans.assign_k == k) for k in np.arange(K)])
        self.ln_p = self.log_likelihood()
    
    def log_likelihood(self):
        Px = np.sum([np.log(
                np.sum(
                    [self.w[k] * self.normal_pdf(x, self.means[k], self.covars[k])
                     for k in range(self.K)]))
                for x in self.X])
        return Px
    
    def normal_pdf(self, x, mu, sigma): # multivariate Gaussian pdf function
        n = len(x)
        px = 1/np.sqrt((2*np.pi)*np.linalg.det(sigma))
        px *= np.exp(-0.5*np.matmul(np.matmul(np.transpose(x-mu), np.linalg.inv(sigma)),(x-mu)))
        return px
    
    def gamma(self, n, k): # E step: γ(z_nk)
        r = self.w[k]*self.normal_pdf(self.X[n], self.means[k], self.covars[k])
        r /= np.sum([self.w[i]*self.normal_pdf(self.X[n], self.means[i], self.covars[i]) for i in range(self.K)])
        return r

    def maximization(self): # M step
        Nk = np.array([np.sum([self.gamma(n,k) for n in range(self.N)]) for k in range(self.K)])
        # Update means  
        means_new = np.array([
            (1/Nk[k]) * np.sum([self.gamma(n,k)*self.X[n] for n in range(self.N)], axis=0) for k in range(self.K)
        ])
        # Update covariance matrices
        covars_new = np.array([
            (1/Nk[k]) * np.sum([self.gamma(n,k)*np.tensordot((X[n]-means_new[k]), (X[n]-means_new[k]), axes=0) 
                    for n in range(self.N)], axis=0) 
        for k in range(self.K)])
        # Update mixing coefficients
        w_new = Nk/self.N 
#         self.new_ln_p = self.log_likelihood()
        return w_new, means_new, covars_new
    
    def EM(self, threshold):
        count = 0
        self.w, self.means, self.covars = self.maximization()
        self.new_ln_p = self.log_likelihood()
        count +=1
        print('Iteration Count: ', count)
        print('Log likelihood error: ', (self.new_ln_p - self.ln_p))
        print('Log likelihood :', self.ln_p, self.new_ln_p)
        while (self.new_ln_p - self.ln_p) > threshold:
            self.ln_p = self.new_ln_p
            self.w, self.means, self.covars = self.maximization()
            self.new_ln_p = self.log_likelihood()
            count +=1
            print('Iteration Count:', count)
            print('Log likelihood error: ', (self.new_ln_p - self.ln_p))
            print('Log likelihood :', self.new_ln_p)
    
    def optimal_params(self):
        return self.w, self.means, self.covars

# %%
d = 2
K = 1
X, means, covars = generate_dataset(d=d, N=100, K=K)
model = GMM(data=X, d=d, K=K)
model.EM(threshold=1e-6)
####################################################
print('*********************************************')
print('Actual Means:')
print(means)
print('Number of mixtures: ', K)
print('Actual Covariances:')
print(covars)
print('-------------------------------')
W, means_hat, covars_hat = model.optimal_params()
print('Estimated Means:') # note: may not be in the same order of the above actual means
print(means_hat)
print('Number of mixtures: ', K)
print('Estimated Covariances:')
print(covars_hat)
print('Mixing Parameters:')
print(W)
# Out:
# Done
# Log likelihood error:  0.005033585350133762
# Log likelihood : -288.00536545712254 -288.0003318717724
# Iteration count:  1
# Iteration Count: 2
# Log likelihood error:  0.0
# Log likelihood : -288.0003318717724
# *********************************************
# Actual Means:
# [[0.50396255 0.35975807]]
# Number of mixtures:  1
# Actual Covariances:
# [[[5.54110627 1.79678892]
#   [1.79678892 2.01709567]]]
# -------------------------------
# Estimated Means:
# [[0.7155803  0.50986425]]
# Number of mixtures:  1
# Estimated Covariances:
# [[[4.48467224 1.12631913]
#   [1.12631913 1.80706505]]]
# Mixing Parameters:
# [1.]

# %%
d = 2
K = 3
X, means, covars = generate_dataset(d=d, N=1000, K=K)
model = GMM(data=X, d=d, K=K)
model.EM(threshold=1e-5)
####################################################
print('*********************************************')
print('Actual Means:')
print(means)
print('Number of mixtures: ', K)
print('Actual Covariances:')
print(covars)
print('-------------------------------')
W, means_hat, covars_hat = model.optimal_params()
print('Estimated Means:') # note: may not be in the same order of the above actual means
print(means_hat)
print('Number of mixtures: ', K)
print('Estimated Covariances:')
print(covars_hat)
print('Mixing Parameters:')
print(W)
# Out:
# Done
# Log likelihood error:  38.23892020144558
# Log likelihood : -2744.4542561304547 -2706.215335929009
# Iteration count:  1
# Iteration Count: 2
# Log likelihood error:  13.96492084729016
# Log likelihood : -2692.250415081719
# Iteration Count: 3
# Log likelihood error:  7.06842506392104
# Log likelihood : -2685.181990017798
# Iteration Count: 4
# Log likelihood error:  4.155628311753844
# Log likelihood : -2681.026361706044
# Iteration Count: 5
# Log likelihood error:  2.6706923037113484
# Log likelihood : -2678.3556694023328
# Iteration Count: 6
# Log likelihood error:  1.8215879800281982
# Log likelihood : -2676.5340814223046
# Iteration Count: 7
# Log likelihood error:  1.2978733454438043
# Log likelihood : -2675.2362080768607
# Iteration Count: 8
# Log likelihood error:  0.9578018634229011
# Log likelihood : -2674.278406213438
# Iteration Count: 9
# Log likelihood error:  0.7287945529810713
# Log likelihood : -2673.549611660457
# Iteration Count: 10
# Log likelihood error:  0.5702732039353577
# Log likelihood : -2672.9793384565214
# Iteration Count: 11
# Log likelihood error:  0.4580425146896232
# Log likelihood : -2672.521295941832
# Iteration Count: 12
# Log likelihood error:  0.37700405129589853
# Log likelihood : -2672.144291890536
# Iteration Count: 13
# Log likelihood error:  0.31742117865678665
# Log likelihood : -2671.826870711879
# Iteration Count: 14
# Log likelihood error:  0.2728532182886738
# Log likelihood : -2671.5540174935904
# Iteration Count: 15
# Log likelihood error:  0.23894877042403095
# Log likelihood : -2671.3150687231664
# Iteration Count: 16
# Log likelihood error:  0.21271390638821686
# Log likelihood : -2671.102354816778
# Iteration Count: 17
# Log likelihood error:  0.19205611085590135
# Log likelihood : -2670.9102987059223
# Iteration Count: 18
# Log likelihood error:  0.17549370238384654
# Log likelihood : -2670.7348050035384
# Iteration Count: 19
# Log likelihood error:  0.161966874335576
# Log likelihood : -2670.572838129203
# Iteration Count: 20
# Log likelihood error:  0.15071228790930036
# Log likelihood : -2670.4221258412936
# Iteration Count: 21
# Log likelihood error:  0.1411780790881494
# Log likelihood : -2670.2809477622054
# Iteration Count: 22
# Log likelihood error:  0.13296502113416864
# Log likelihood : -2670.1479827410712
# Iteration Count: 23
# Log likelihood error:  0.12578495945217583
# Log likelihood : -2670.022197781619
# Iteration Count: 24
# Log likelihood error:  0.11943092484125373
# Log likelihood : -2669.902766856778
# Iteration Count: 25
# Log likelihood error:  0.11375535456409125
# Log likelihood : -2669.7890115022137
# Iteration Count: 26
# Log likelihood error:  0.10865409790676495
# Log likelihood : -2669.680357404307
# Iteration Count: 27
# Log likelihood : -2409.092251131474
# Iteration Count: 124
# Log likelihood error:  0.0003521680291669327
# Log likelihood : -2409.0918989634447
# Iteration Count: 125
# Log likelihood error:  0.0002915695877163671
# Log likelihood : -2409.091607393857
# Iteration Count: 126
# Log likelihood error:  0.00024135856574503123
# Log likelihood : -2409.0913660352912
# Iteration Count: 127
# Log likelihood error:  0.0001997646390918817
# Log likelihood : -2409.091166270652
# Iteration Count: 128
# Log likelihood error:  0.00016531588335055858
# Log likelihood : -2409.091000954769
# Iteration Count: 129
# Log likelihood error:  0.00013679022094947868
# Log likelihood : -2409.090864164548
# Iteration Count: 130
# Log likelihood error:  0.00011317413054712233
# Log likelihood : -2409.0907509904173
# Iteration Count: 131
# Log likelihood error:  9.362519358546706e-05
# Log likelihood : -2409.0906573652237
# Iteration Count: 132
# Log likelihood error:  7.74457648731186e-05
# Log likelihood : -2409.090579919459
# Iteration Count: 133
# Log likelihood error:  6.405694648492499e-05
# Log likelihood : -2409.0905158625123
# Iteration Count: 134
# Log likelihood error:  5.297846155372099e-05
# Log likelihood : -2409.090462884051
# Iteration Count: 135
# Log likelihood error:  4.3812669900944456e-05
# Log likelihood : -2409.090419071381
# Iteration Count: 136
# Log likelihood error:  3.623082102421904e-05
# Log likelihood : -2409.09038284056
# Iteration Count: 137
# Log likelihood error:  2.995870090671815e-05
# Log likelihood : -2409.090352881859
# Iteration Count: 138
# Log likelihood error:  2.47713455792109e-05
# Log likelihood : -2409.0903281105134
# Iteration Count: 139
# Log likelihood error:  2.048094665951794e-05
# Log likelihood : -2409.0903076295667
# Iteration Count: 140
# Log likelihood error:  1.6933187453105347e-05
# Log likelihood : -2409.0902906963793
# Iteration Count: 141
# Log likelihood error:  1.399917800881667e-05
# Log likelihood : -2409.0902766972013
# Iteration Count: 142
# Log likelihood error:  1.1573210485948948e-05
# Log likelihood : -2409.090265123991
# Iteration Count: 143
# Log likelihood error:  9.567220786266262e-06
# Log likelihood : -2409.09025555677
# *********************************************
# Actual Means:
# [[0.58970652 0.3454566 ]
#  [1.2044872  1.59085514]
#  [2.02313431 2.81395392]]
# Number of mixtures:  3
# Actual Covariances:
# [[[4.1788555  5.22601287]
#   [5.22601287 6.6751997 ]]
#
#  [[6.7956636  6.72558698]
#   [6.72558698 7.58871909]]
#
#  [[4.91130382 5.07369457]
#   [5.07369457 5.24204917]]]
# -------------------------------
# Estimated Means:
# [[1.83419267 2.6183028 ]
#  [1.26774603 1.65750546]
#  [0.40473359 0.06507164]]
# Number of mixtures:  3
# Estimated Covariances:
# [[[4.97110893 5.13246589]
#   [5.13246589 5.29969956]]
#
#  [[7.39046775 7.13557923]
#   [7.13557923 7.78862428]]
#
#  [[3.87132313 4.7851385 ]
#   [4.7851385  6.02663022]]]
# Mixing Parameters:
# [0.19217001 0.57547722 0.23235277]

# %%
d = 5
K = 10
X, means, covars = generate_dataset(d=d, N=2000, K=K)
model = GMM(data=X, d=d, K=K)
model.EM(threshold=1e-4)
####################################################
print('*********************************************')
print('Actual Means:')
print(means)
print('Number of mixtures: ', K)
print('Actual Covariances:')
print(covars)
print('-------------------------------')
W, means_hat, covars_hat = model.optimal_params()
print('Estimated Means:') # note: may not be in the same order of the above actual means
print(means_hat)
print('Number of mixtures: ', K)
print('Estimated Covariances:')
print(covars_hat)
print('Mixing Parameters:')
print(W)
# Out:
# Done
# Log likelihood error:  212.79301396342998
# Log likelihood : -16707.234835159 -16494.44182119557
# Iteration count:  1
# Iteration Count: 2
# Log likelihood error:  123.45495088104326
# Log likelihood : -16370.986870314528
# Iteration Count: 3
# Log likelihood error:  125.34061248641046
# Log likelihood : -16245.646257828117
# Iteration Count: 4
# Log likelihood error:  162.90216686210988
# Log likelihood : -16082.744090966007
# Iteration Count: 5
# Log likelihood error:  241.54601548204482
# Log likelihood : -15841.198075483962
# Iteration Count: 6
# Log likelihood error:  378.43996693519875
# Log likelihood : -15462.758108548764
# Iteration Count: 7
# Log likelihood error:  480.20282143470286
# Log likelihood : -14982.55528711406
# Iteration Count: 8
# Log likelihood error:  481.77281905843483
# Log likelihood : -14500.782468055626
# Iteration Count: 9
# Log likelihood error:  312.22930095393167
# Log likelihood : -14188.553167101694
# Iteration Count: 10
# Log likelihood error:  66.20490133164276
# Log likelihood : -14122.348265770052
# Iteration Count: 11
# Log likelihood error:  30.766630693147818
# Log likelihood : -14091.581635076904
# Iteration Count: 12
# Log likelihood error:  23.04749422547684
# Log likelihood : -14068.534140851427
# Iteration Count: 13
# Log likelihood error:  23.605667352328965
# Log likelihood : -14044.928473499098
# Iteration Count: 14
# Log likelihood error:  25.909525385068264
# Log likelihood : -14019.01894811403
# Iteration Count: 15
# Log likelihood error:  28.211875908435104
# Log likelihood : -13990.807072205595
# Iteration Count: 16
# Log likelihood error:  28.801931532363596
# Log likelihood : -13962.005140673231
# Iteration Count: 17
# Log likelihood error:  30.566409632265277
# Log likelihood : -13931.438731040966
# Iteration Count: 18
# Log likelihood error:  31.90804996388397
# Log likelihood : -13899.530681077082
# Iteration Count: 19
# Log likelihood error:  29.3263556381753
# Log likelihood : -13870.204325438906
# Iteration Count: 20
# Log likelihood error:  25.09527683254055
# Log likelihood : -13845.109048606366
# Iteration Count: 21
# Log likelihood error:  20.531867044908722
# Log likelihood : -13824.577181561457
# Iteration Count: 22
# Log likelihood error:  18.047688139165984
# Log likelihood : -13806.529493422291
# Iteration Count: 23
# Log likelihood error:  13.567373203823081
# Log likelihood : -13792.962120218468
# Iteration Count: 24
# Log likelihood error:  8.60835595547178
# Log likelihood : -13784.353764262996
# Iteration Count: 25
# Log likelihood error:  5.709098068864478
# Log likelihood : -13778.644666194132
# Iteration Count: 26
# Log likelihood error:  4.689813069426236
# Log likelihood : -13773.954853124706
# Iteration Count: 27
# Log likelihood error:  4.3795121244002075
# Log likelihood : -13769.575341000305
# Iteration Count: 28
# Log likelihood error:  4.092655044292769
# Log likelihood : -13765.482685956013
# Iteration Count: 29
# Log likelihood error:  3.756251117651118
# Log likelihood : -13761.726434838361
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-6d51d28d2463> in <module>()
#       3 X, means, covars = generate_dataset(d=d, N=2000, K=K)
#       4 model = GMM(data=X, d=d, K=K)
# ----> 5 model.EM(threshold=1e-4)
#       6 ####################################################
#       7 print('*********************************************')
#
# <ipython-input-92-f596d067b53f> in EM(self, threshold)
#      61         while (self.new_ln_p - self.ln_p) > threshold:
#      62             self.ln_p = self.new_ln_p
# ---> 63             self.w, self.means, self.covars = self.maximization()
#      64             self.new_ln_p = self.log_likelihood()
#      65             count +=1
#
# <ipython-input-92-f596d067b53f> in maximization(self)
#      45             (1/Nk[k]) * np.sum([self.gamma(n,k)*np.tensordot((X[n]-means_new[k]), (X[n]-means_new[k]), axes=0)
#      46                     for n in range(self.N)], axis=0)
# ---> 47         for k in range(self.K)])
#      48         # Update mixing coefficients
#      49         w_new = Nk/self.N
#
# <ipython-input-92-f596d067b53f> in <listcomp>(.0)
#      45             (1/Nk[k]) * np.sum([self.gamma(n,k)*np.tensordot((X[n]-means_new[k]), (X[n]-means_new[k]), axes=0)
#      46                     for n in range(self.N)], axis=0)
# ---> 47         for k in range(self.K)])
#      48         # Update mixing coefficients
#      49         w_new = Nk/self.N
#
# <ipython-input-92-f596d067b53f> in <listcomp>(.0)
#      44         covars_new = np.array([
#      45             (1/Nk[k]) * np.sum([self.gamma(n,k)*np.tensordot((X[n]-means_new[k]), (X[n]-means_new[k]), axes=0)
# ---> 46                     for n in range(self.N)], axis=0)
#      47         for k in range(self.K)])
#      48         # Update mixing coefficients
#
# <ipython-input-92-f596d067b53f> in gamma(self, n, k)
#      32     def gamma(self, n, k): # E step: γ(z_nk)
#      33         r = self.w[k]*self.normal_pdf(self.X[n], self.means[k], self.covars[k])
# ---> 34         r /= np.sum([self.w[i]*self.normal_pdf(self.X[n], self.means[i], self.covars[i]) for i in range(self.K)])
#      35         return r
#      36
#
# <ipython-input-92-f596d067b53f> in <listcomp>(.0)
#      32     def gamma(self, n, k): # E step: γ(z_nk)
#      33         r = self.w[k]*self.normal_pdf(self.X[n], self.means[k], self.covars[k])
# ---> 34         r /= np.sum([self.w[i]*self.normal_pdf(self.X[n], self.means[i], self.covars[i]) for i in range(self.K)])
#      35         return r
#      36
#
# <ipython-input-92-f596d067b53f> in normal_pdf(self, x, mu, sigma)
#      27         n = len(x)
#      28         px = 1/np.sqrt((2*np.pi)*np.linalg.det(sigma))
# ---> 29         px *= np.exp(-0.5*np.matmul(np.matmul(np.transpose(x-mu), np.linalg.inv(sigma)),(x-mu)))
#      30         return px
#      31
#
# ~/.local/lib/python3.5/site-packages/numpy/linalg/linalg.py in inv(a)
#     530     signature = 'D->D' if isComplexType(t) else 'd->d'
#     531     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 532     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     533     return wrap(ainv.astype(result_t, copy=False))
#     534
#
# KeyboardInterrupt:
