# %% [markdown]
# # AI and ML - Homework

# %%
# imports
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate training samples
N = 10 # Number of training samples
# Generate equispaced floats in the interval [0, 2π]
x = np.linspace(0, 2*np.pi, N)
# Generate noise
mean = 0
std = 0.05
# Generate some numbers from the sine function
y = np.sin(x)
# Add noise
y += np.random.normal(mean, std, N)

# put column with ones for bias
x_train = np.array([np.ones(N), x])
# swap axes changes the above 2xN matrix to Nx2 matrix
x_train = np.swapaxes(x_train, 0,1)
print(x_train.shape)
# Out:
# (10, 2)

# %%
# Generate test inputs
N_test = 100
x_test = np.linspace(0,2*np.pi, N_test)
test_mean = 0
test_std = 0.05
x_test += np.random.normal(test_mean, test_std, N_test)
y_test = np.sin(x_test)
# x_test = np.array([np.ones(N_test), x_test])
# x_test = np.swapaxes(x_test, 0,1)
# print(x_test.shape)

# %% [markdown]
# ### Maximum likelihood weight estimation assuming that the labels follow a Gaussian distribution when conditioned on the inputs and weights
# model: y = w1*x + w0
#
# y follows Gaussian distribution with mean = **X*w** and var = 1/β

# %%
def get_weights(X, y):
    w = np.dot(np.dot(np.linalg.inv(np.dot(np.transpose(X),X)), np.transpose(X)), y)
    return w

# %%
w = get_weights(x_train, y)
y_predicted = w[0] + w[1]*x_test   # y=mx+c
inv_beta = np.dot(np.transpose(y_test - y_predicted), (y_test - y_predicted)) / N_test
beta = 1/inv_beta
print(beta)
# noisy labels following distribution mentioned above
y_hat = np.random.normal(y_predicted, np.sqrt(inv_beta), N_test)

# plotting
plt.figure(1)
plt.plot(x, y, 'ro')
plt.plot(x_test, y_predicted, 'bo')
plt.xlabel('x')
plt.ylabel('Sin(x)')
plt.figure(2)
plt.plot(x_test,y_hat,'bo')
plt.plot(x_test, y_predicted, 'ro')
plt.xlabel('x')
plt.ylabel('Sin(x)')
plt.show()
# Out:
# 4.66217064724378

# %%
# with label noise std = 0.4
y = np.sin(x) + np.random.normal(0, 0.4, N)
w = get_weights(x_train, y)
y_predicted = w[0] + w[1]*x_test   # y=mx+c
inv_beta = np.dot(np.transpose(y_test - y_predicted), (y_test - y_predicted)) / N_test
beta = 1/inv_beta
print(beta)
# noisy labels following distribution mentioned above
y_hat = np.random.normal(y_predicted, np.sqrt(inv_beta), N_test)

# plotting
plt.figure(1)
plt.plot(x, y, 'ro')
plt.plot(x_test, y_predicted, 'bo')
plt.xlabel('x')
plt.ylabel('Sin(x)')alpha
plt.figure(2)
plt.plot(x_test,y_hat,'bo')
plt.plot(x_test, y_predicted, 'ro')
plt.xlabel('x')
plt.ylabel('Sin(x)')
plt.show()
# Out:
# 4.1496888272820005
